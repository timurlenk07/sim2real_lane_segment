# %% [markdown]
# # Data preparation
# Takes the videos, both annotated and original ones and takes each frame apart for learning on individual images.

# %%
# !git clone https://github.com/timurlenk07/onlab_duckietown -b data
# Out:
# Cloning into 'onlab_duckietown'...
# remote: Enumerating objects: 613, done.
# remote: Total 613 (delta 0), reused 0 (delta 0), pack-reused 613
# Receiving objects: 100% (613/613), 2.41 GiB | 49.62 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# Checking out files: 100% (110/110), done.

# %%
# !mv onlab_duckietown/data data && rm onlab_duckietown -r
# Out:
# rm: cannot remove 'onlab_duckietown': Is a directory

# %%
# import required libraries
import cv2
import os
import glob
import logging
import concurrent.futures
import numpy as np
import keras

# Set random seeds
np.random.seed(2019)
from tensorflow import set_random_seed
set_random_seed(1118)

keras.__version__
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c69b9ea4d3a0> in <module>
#      10 # Set random seeds
#      11 np.random.seed(2019)
# ---> 12 from tensorflow import set_random_seed
#      13 set_random_seed(1118)
#      14
#
# ImportError: cannot import name 'set_random_seed'

# %% [markdown]
# The below code iterates through all the videos in a directory and cuts them into single images. To fasten up this process multithreading was applied.

# %%
logging.basicConfig(level=logging.INFO, format='[%(levelname)s]: %(message)s')

train_dir = os.path.join(os.getcwd(), 'data', "train")
valid_dir = os.path.join(os.getcwd(), 'data', "validation")
test_dir = os.path.join(os.getcwd(), 'data', "test")
dirs = [train_dir, valid_dir, test_dir]

new_res = (160, 120)

def video2images(directory):
    logging.info(f"Managing directory: {directory}")

    # Get the list of available recordings
    annot_vids = sorted(glob.glob(os.path.join(directory, '*_annot_pp.avi')))
    orig_vids = sorted(glob.glob(os.path.join(directory, '*_orig_pp.avi')))

    # Check whether original and annotated recordings number match or not
    assert len(annot_vids) == len(orig_vids)
    
    logging.info(f"{directory} Number of files found: {len(annot_vids)}. Taking apart video files...")

    os.makedirs(os.path.join(directory, 'orig'))
    os.makedirs(os.path.join(directory, 'annot'))

    img_counter = 0
    vid_counter = 0
    # Iterate and postprocess every recording
    for vid_a, vid_o in zip(annot_vids, orig_vids):

        # Open recordings...
        cap_orig = cv2.VideoCapture(vid_o)
        cap_annot = cv2.VideoCapture(vid_a)
        if not cap_orig.isOpened() or not cap_annot.isOpened():
            logging.warning(f"{directory} Could not open file nr. {vid_counter}! Continuing...", )
            continue
        
        # Check whether recordings hold the same number of frames
        if cap_orig.get(cv2.CAP_PROP_FRAME_COUNT) != cap_annot.get(cv2.CAP_PROP_FRAME_COUNT):
            logging.warning(f"{directory} Different video length encountered in video nr. {vid_counter}! Continuing...")
            continue
        
        
        # Produce output videos
        logging.debug(f"{directory} Processing recording nr. {vid_counter}...")
        while cap_orig.isOpened() and cap_annot.isOpened(): # Iterate through every frame
            ret_o, frame_o = cap_orig.read()
            ret_a, frame_a = cap_annot.read()
            if not ret_o or not ret_a:
                break

            frame_o = cv2.resize(frame_o, new_res)
            frame_a = cv2.cvtColor(frame_a, cv2.COLOR_BGR2GRAY)
            frame_a = cv2.resize(frame_a, new_res)

            filename = str(img_counter).zfill(6) + '.png'
            filepath_o = os.path.join(directory, 'orig', filename)
            filepath_a = os.path.join(directory, 'annot', filename)
            # Save both frames in new file
            cv2.imwrite(filepath_o, frame_o)
            cv2.imwrite(filepath_a, frame_a)

            img_counter += 1

        
        logging.debug(f"{directory} Processing of recording nr. {vid_counter} done.")
        vid_counter += 1
        
        # Release VideoCapture resources
        cap_orig.release()
        cap_annot.release()

        os.remove(vid_a)
        os.remove(vid_o)

    logging.info(f"{directory} Video files taken apart! Images generated: {img_counter}")

with concurrent.futures.ThreadPoolExecutor() as executor:
    futures_of_images = [executor.submit(video2images, directory) for directory in dirs]
    
    concurrent.futures.wait(futures_of_images)
# Out:
# [INFO]: Managing directory: /content/data/train
# [INFO]: /content/data/train Number of files found: 33. Taking apart video files...
# [INFO]: Managing directory: /content/data/validation
# [INFO]: /content/data/validation Number of files found: 11. Taking apart video files...
# [INFO]: Managing directory: /content/data/test
# [INFO]: /content/data/test Number of files found: 11. Taking apart video files...
# [INFO]: /content/data/test Video files taken apart! Images generated: 1178
# [INFO]: /content/data/validation Video files taken apart! Images generated: 1963
# [INFO]: /content/data/train Video files taken apart! Images generated: 5352

# %% [markdown]
# Set variables for easier data access in later code.

# %%
train_x_dir = os.path.join(train_dir, 'orig')
train_y_dir = os.path.join(train_dir, 'annot')
valid_x_dir = os.path.join(valid_dir, 'orig')
valid_y_dir = os.path.join(valid_dir, 'annot')
test_x_dir = os.path.join(test_dir, 'orig')
test_y_dir = os.path.join(test_dir, 'annot')

train_cnt = len(glob.glob(os.path.join(train_x_dir, '*.png')))
valid_cnt = len(glob.glob(os.path.join(valid_x_dir, '*.png')))
test_cnt = len(glob.glob(os.path.join(test_x_dir, '*.png')))

assert train_cnt == len(glob.glob(os.path.join(train_y_dir, '*.png')))
assert valid_cnt == len(glob.glob(os.path.join(valid_y_dir, '*.png')))
assert test_cnt == len(glob.glob(os.path.join(test_y_dir, '*.png')))

print(f"Train set count: {train_cnt}")
print(f"Valid set count: {valid_cnt}")
print(f"Test set count: {test_cnt}")
# Out:
# Train set count: 5352
# Valid set count: 1963
# Test set count: 1178

# %% [markdown]
# # Model creation and training
# We define custom generators to create batches of learning data. Then we will create our model and initialize all necessary callbacks for efficient learning. Then we fit our generators until stop conditions are satisfied.

# %%
def data_generator(batch_size, total_count, inputs_dir, outputs_dir):
    while True:
        # read batch size random indexed images
        t_idxs = np.random.randint(0, total_count, batch_size)
        x_shape = (batch_size, 120, 160, 3)
        y_shape = (batch_size, 120, 160)
        x = np.zeros(shape=x_shape, dtype=np.float32)
        y = np.zeros(shape=y_shape, dtype=np.float32)

        for i, idx in enumerate(t_idxs):
            filename = f'{idx:06d}.png'
            x[i] = cv2.imread(os.path.join(inputs_dir, filename))
            y[i] = cv2.imread(os.path.join(outputs_dir, filename), cv2.IMREAD_GRAYSCALE) 
        
        yield (x/255,y/255)

steps_per_epoch = 200
train_batch_size = int(train_cnt / steps_per_epoch)
valid_batch_size = int(valid_cnt / steps_per_epoch)
test_batch_size = int(test_cnt / steps_per_epoch)
train_gen = data_generator(train_batch_size, train_cnt, train_x_dir, train_y_dir)
valid_gen = data_generator(valid_batch_size, valid_cnt, valid_x_dir, valid_y_dir)
test_gen = data_generator(test_batch_size, test_cnt, test_x_dir, test_y_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1205eb97d9e> in <module>
#      16
#      17 steps_per_epoch = 200
# ---> 18 train_batch_size = int(train_cnt / steps_per_epoch)
#      19 valid_batch_size = int(valid_cnt / steps_per_epoch)
#      20 test_batch_size = int(test_cnt / steps_per_epoch)
#
# NameError: name 'train_cnt' is not defined

# %% [markdown]
# Our model consists of an encoder half-network that is followed by a decoder half-network, with sigmoid activation applied to the combined output of the last decoder layer.

# %%
kernel_size = (6,8)
filters = 64

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=(120, 160, 3)))    # RGB image goes in

# ENCODER
# --------------------
for _ in range(3):
    for _ in range(2):
        model.add(keras.layers.Conv2D(filters=filters,
                                        kernel_size=kernel_size,
                                        strides=1,
                                        padding='same',
                                        use_bias=True,
                                        bias_initializer=keras.initializers.constant(value=0.0)))
        model.add(keras.layers.BatchNormalization())
        model.add(keras.layers.ReLU())

    model.add(keras.layers.MaxPool2D(pool_size=2, strides=2))
    filters *= 2
# --------------------

# DECODER
# --------------------
for _ in range(3):
    filters = round(filters/2)
    model.add(keras.layers.UpSampling2D(size=2,
                                        interpolation='nearest'))
    for _ in range(2):
        model.add(keras.layers.Conv2D(filters=filters,
                                        kernel_size=kernel_size,
                                        strides=1,
                                        padding='same',
                                        use_bias=True,
                                        bias_initializer=keras.initializers.constant(value=0.0)))
        model.add(keras.layers.BatchNormalization())       
        model.add(keras.layers.ReLU())
# --------------------

model.add(keras.layers.Dense(units=1,
                                activation='sigmoid',
                                use_bias=True
))
model.add(keras.layers.Reshape((120,160)))

# %%
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3), loss="binary_crossentropy", metrics=['acc'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 120, 160, 64)      9280
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 120, 160, 64)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 120, 160, 64)      196672
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 120, 160, 64)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 60, 80, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 60, 80, 128)       393344
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 60, 80, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 60, 80, 128)       786560
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 60, 80, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 40, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 30, 40, 256)       1573120
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 40, 256)       3145984
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 30, 40, 256)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 20, 256)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 30, 40, 256)       3145984
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 30, 40, 256)       3145984
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 30, 40, 256)       0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 60, 80, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 60, 80, 128)       1572992
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 60, 80, 128)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 60, 80, 128)       786560
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 60, 80, 128)       0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 120, 160, 128)     0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 120, 160, 64)      393280
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 120, 160, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 120, 160, 64)      196672
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 120, 160, 64)      0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120, 160, 1)       65
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 120, 160)          0
# =================================================================
# Total params: 15,353,665
# Trainable params: 15,350,081
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# As we see we have about 15M parameters and practically all of them are up for training. Now we should define our callbacks.

# %%
checkpoint_name = 'rightlane_segment.hdf5'
callback_checkpoint = keras.callbacks.ModelCheckpoint(filepath=checkpoint_name,
                                                          monitor='val_loss',
                                                          verbose=1,
                                                          save_weights_only=True,
                                                          save_best_only=True)

callback_early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',
                                         patience=10, verbose=1)
callback_reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                          factor=0.1,
                                                          patience=7,
                                                          verbose=1,
                                                          min_rl=1e-5)

# %% [markdown]
# We are ready for training! We apply our generator functions to the fit_generator function of our model.

# %%
model.fit_generator(
    generator=train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=50,
    verbose=1,
    validation_data=valid_gen,
    validation_steps=steps_per_epoch,
    callbacks=[callback_checkpoint, callback_reduce_lr, callback_early_stopping]
)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 122s 611ms/step - loss: 0.2416 - acc: 0.8930 - val_loss: 0.1682 - val_acc: 0.9318
#
# Epoch 00001: val_loss improved from inf to 0.16824, saving model to rightlane_segment.hdf5
# Epoch 2/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0802 - acc: 0.9675 - val_loss: 0.1029 - val_acc: 0.9578
#
# Epoch 00002: val_loss improved from 0.16824 to 0.10291, saving model to rightlane_segment.hdf5
# Epoch 3/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0620 - acc: 0.9739 - val_loss: 0.0911 - val_acc: 0.9639
#
# Epoch 00003: val_loss improved from 0.10291 to 0.09111, saving model to rightlane_segment.hdf5
# Epoch 4/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0401 - acc: 0.9817 - val_loss: 0.0739 - val_acc: 0.9697
#
# Epoch 00004: val_loss improved from 0.09111 to 0.07394, saving model to rightlane_segment.hdf5
# Epoch 5/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0394 - acc: 0.9819 - val_loss: 0.0619 - val_acc: 0.9738
#
# Epoch 00005: val_loss improved from 0.07394 to 0.06188, saving model to rightlane_segment.hdf5
# Epoch 6/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0345 - acc: 0.9837 - val_loss: 0.0366 - val_acc: 0.9834
#
# Epoch 00006: val_loss improved from 0.06188 to 0.03660, saving model to rightlane_segment.hdf5
# Epoch 7/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0265 - acc: 0.9868 - val_loss: 0.5749 - val_acc: 0.7938
#
# Epoch 00007: val_loss did not improve from 0.03660
# Epoch 8/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0234 - acc: 0.9880 - val_loss: 0.0604 - val_acc: 0.9760
#
# Epoch 00008: val_loss did not improve from 0.03660
# Epoch 9/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0338 - acc: 0.9842 - val_loss: 2.2830 - val_acc: 0.6590
#
# Epoch 00009: val_loss did not improve from 0.03660
# Epoch 10/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0252 - acc: 0.9873 - val_loss: 0.0283 - val_acc: 0.9868
#
# Epoch 00010: val_loss improved from 0.03660 to 0.02833, saving model to rightlane_segment.hdf5
# Epoch 11/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0202 - acc: 0.9893 - val_loss: 0.0271 - val_acc: 0.9874
#
# Epoch 00011: val_loss improved from 0.02833 to 0.02706, saving model to rightlane_segment.hdf5
# Epoch 12/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0178 - acc: 0.9902 - val_loss: 0.0222 - val_acc: 0.9894
#
# Epoch 00012: val_loss improved from 0.02706 to 0.02224, saving model to rightlane_segment.hdf5
# Epoch 13/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0176 - acc: 0.9903 - val_loss: 0.0316 - val_acc: 0.9868
#
# Epoch 00013: val_loss did not improve from 0.02224
# Epoch 14/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0376 - acc: 0.9828 - val_loss: 0.0348 - val_acc: 0.9843
#
# Epoch 00014: val_loss did not improve from 0.02224
# Epoch 15/50
# 200/200 [==============================] - 117s 583ms/step - loss: 0.0203 - acc: 0.9892 - val_loss: 0.0261 - val_acc: 0.9875
#
# Epoch 00015: val_loss did not improve from 0.02224
# Epoch 16/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0166 - acc: 0.9907 - val_loss: 0.0244 - val_acc: 0.9882
#
# Epoch 00016: val_loss did not improve from 0.02224
# Epoch 17/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0151 - acc: 0.9913 - val_loss: 0.0229 - val_acc: 0.9895
#
# Epoch 00017: val_loss did not improve from 0.02224
# Epoch 18/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0146 - acc: 0.9915 - val_loss: 0.0214 - val_acc: 0.9900
#
# Epoch 00018: val_loss improved from 0.02224 to 0.02136, saving model to rightlane_segment.hdf5
# Epoch 19/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0187 - acc: 0.9899 - val_loss: 0.0275 - val_acc: 0.9867
#
# Epoch 00019: val_loss did not improve from 0.02136
# Epoch 20/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0160 - acc: 0.9911 - val_loss: 0.0289 - val_acc: 0.9879
#
# Epoch 00020: val_loss did not improve from 0.02136
# Epoch 21/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0147 - acc: 0.9914 - val_loss: 0.0211 - val_acc: 0.9900
#
# Epoch 00021: val_loss improved from 0.02136 to 0.02105, saving model to rightlane_segment.hdf5
# Epoch 22/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0128 - acc: 0.9922 - val_loss: 0.0191 - val_acc: 0.9905
#
# Epoch 00022: val_loss improved from 0.02105 to 0.01914, saving model to rightlane_segment.hdf5
# Epoch 23/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0122 - acc: 0.9924 - val_loss: 0.0210 - val_acc: 0.9904
#
# Epoch 00023: val_loss did not improve from 0.01914
# Epoch 24/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0115 - acc: 0.9927 - val_loss: 0.0201 - val_acc: 0.9908
#
# Epoch 00024: val_loss did not improve from 0.01914
# Epoch 25/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0115 - acc: 0.9927 - val_loss: 0.0230 - val_acc: 0.9901
#
# Epoch 00025: val_loss did not improve from 0.01914
# Epoch 26/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0115 - acc: 0.9927 - val_loss: 0.0172 - val_acc: 0.9912
#
# Epoch 00026: val_loss improved from 0.01914 to 0.01719, saving model to rightlane_segment.hdf5
# Epoch 27/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0149 - acc: 0.9915 - val_loss: 5.3934 - val_acc: 0.6170
#
# Epoch 00027: val_loss did not improve from 0.01719
# Epoch 28/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0287 - acc: 0.9860 - val_loss: 0.0451 - val_acc: 0.9827
#
# Epoch 00028: val_loss did not improve from 0.01719
# Epoch 29/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0160 - acc: 0.9910 - val_loss: 0.0239 - val_acc: 0.9889
#
# Epoch 00029: val_loss did not improve from 0.01719
# Epoch 30/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0126 - acc: 0.9923 - val_loss: 0.0197 - val_acc: 0.9905
#
# Epoch 00030: val_loss did not improve from 0.01719
# Epoch 31/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0116 - acc: 0.9927 - val_loss: 0.0192 - val_acc: 0.9910
#
# Epoch 00031: val_loss did not improve from 0.01719
# Epoch 32/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0107 - acc: 0.9930 - val_loss: 0.0154 - val_acc: 0.9918
#
# Epoch 00032: val_loss improved from 0.01719 to 0.01536, saving model to rightlane_segment.hdf5
# Epoch 33/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0106 - acc: 0.9930 - val_loss: 0.0215 - val_acc: 0.9905
#
# Epoch 00033: val_loss did not improve from 0.01536
# Epoch 34/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0108 - acc: 0.9930 - val_loss: 0.0186 - val_acc: 0.9911
#
# Epoch 00034: val_loss did not improve from 0.01536
# Epoch 35/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0103 - acc: 0.9931 - val_loss: 0.0181 - val_acc: 0.9913
#
# Epoch 00035: val_loss did not improve from 0.01536
# Epoch 36/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0098 - acc: 0.9934 - val_loss: 0.0185 - val_acc: 0.9913
#
# Epoch 00036: val_loss did not improve from 0.01536
# Epoch 37/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0101 - acc: 0.9932 - val_loss: 0.0195 - val_acc: 0.9914
#
# Epoch 00037: val_loss did not improve from 0.01536
# Epoch 38/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0097 - acc: 0.9934 - val_loss: 0.0196 - val_acc: 0.9913
#
# Epoch 00038: val_loss did not improve from 0.01536
# Epoch 39/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0094 - acc: 0.9935 - val_loss: 0.0181 - val_acc: 0.9915
#
# Epoch 00039: val_loss did not improve from 0.01536
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 40/50
# 200/200 [==============================] - 116s 582ms/step - loss: 0.0081 - acc: 0.9940 - val_loss: 0.0180 - val_acc: 0.9918
#
# Epoch 00040: val_loss did not improve from 0.01536
# Epoch 41/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0080 - acc: 0.9940 - val_loss: 0.0186 - val_acc: 0.9920
#
# Epoch 00041: val_loss did not improve from 0.01536
# Epoch 42/50
# 200/200 [==============================] - 116s 581ms/step - loss: 0.0078 - acc: 0.9941 - val_loss: 0.0223 - val_acc: 0.9912
#
# Epoch 00042: val_loss did not improve from 0.01536
# Epoch 00042: early stopping

# %% [markdown]
# It looks as our model was able to learn and since we are satisfied with the resultant metrics we will reload our last checkpoint.

# %%
# load best model
try:
    model.load_weights(checkpoint_name)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %% [markdown]
# # Evaluation
# We will take a couple of samples from test data and evaluate our algorithm on those unseen pictures. This will allow us to analize the generalization of our model.

# %%
from google.colab.patches import cv2_imshow

def predict(num):
    x, y = next(test_gen)
    x = x[:num]
    y = y[:num]
    p = [model.predict(np.expand_dims(x[i], axis=0))[0] for i in range(len(x))]
    for r in range(len(x)):
        a = np.array(x[r])*255
        b = np.zeros(shape=x[r].shape)
        c = np.zeros(shape=x[r].shape)
        for i in range(120):
            for j in range(160):
                b[i,j,0] = y[r][i,j]
                b[i,j,1] = y[r][i,j]
                b[i,j,2] = y[r][i,j]
                c[i,j,0] = p[r][i,j]
                c[i,j,1] = p[r][i,j]
                c[i,j,2] = p[r][i,j]
        b = b*255
        c = c*255
        img = np.concatenate((a, b, c), axis=1)
        cv2_imshow(img)

# %%
predict(5)
# Out:
# <PIL.Image.Image image mode=RGB size=480x120 at 0x7F0B014C2F60>
# <PIL.Image.Image image mode=RGB size=480x120 at 0x7F07285E3748>
# <PIL.Image.Image image mode=RGB size=480x120 at 0x7F0B014883C8>
# <PIL.Image.Image image mode=RGB size=480x120 at 0x7F07285E3780>
# <PIL.Image.Image image mode=RGB size=480x120 at 0x7F07285E3780>

# %% [markdown]
# It looks as our model was able to predict quite correctly the right lane in the simulated environment. Some noises appear at some point but overall the accuracy is adequate.
